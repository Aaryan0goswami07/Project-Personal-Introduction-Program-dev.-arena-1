# %%
# personal_intro.py
# Friendly Intro Program

print("🌟 Welcome to the Friendly Intro Program! 🌟")
print("-" * 45)

# this is me  
name = "Aaryan Goswami"
age = "19"
hobby = "learning new things"
city = "Jaipur"
dream = "to be remembered as someone who changed the world one day"

#  output of what i did
print("\n" + "=" * 50)
print(f"👋 Hello {name}!")
print(f"🎂 You're {age} years old.")
print(f"🎯 Your hobby is {hobby}.")
print(f"📍 You're currently in {city}.")
print(f"🚀 Your dream is: {dream}")
print("\n✨ That's amazing, Aaryan! Keep learning and growing — you're destined for greatness. ✨")
print("=" * 50)
# Out:
# 🌟 Welcome to the Friendly Intro Program! 🌟
# ---------------------------------------------
#
# ...
# 👋 Hello Aaryan Goswami!
# 🎂 You're 19 years old.
# 🎯 Your hobby is learning new things.
# 📍 You're currently in Jaipur.
# 🚀 Your dream is: to be remembered as someone who changed the world one day
#
# ✨ That's amazing, Aaryan! Keep learning and growing — you're destined for greatness. ✨
# ...
